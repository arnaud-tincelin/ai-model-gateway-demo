# %% [markdown]
# # AI Model Gateway Demo - Deployment Notebook
#
# This notebook orchestrates the full deployment of the AI Model Gateway infrastructure and agents.
#
# ## Steps:
# 1. Deploy `infra/hub` - API Management and Azure OpenAI resources
# 2. Deploy `infra/spoke` - AI Foundry project with Model Gateway connection
# 3. Generate `.env` file from Terraform outputs
# 4. Deploy and test the agent

# %% [markdown]
# ## Configuration

# %%
# Install required packages (skip if already installed)
# %pip install -q "azure-ai-projects>=2.0.0b3" "azure-identity>=1.25.1"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import os
import subprocess

LOCATION = "swedencentral"
HUB_DIR = "infra/hub"
SPOKE_DIR = "infra/spoke"
os.environ["ARM_SUBSCRIPTION_ID"] = ""
os.environ["ARM_TENANT_ID"] = ""
os.environ["AZURE_TENANT_ID"] = ""

# %% [markdown]
# ## Helper Functions

# %%
def run_terraform(working_dir: str, command: list[str], capture_output: bool = False) -> subprocess.CompletedProcess:
    """Run a terraform command in the specified directory."""
    full_command = ["terraform"] + command
    print(f"📂 {working_dir}")
    print(f"🔧 Running: {' '.join(full_command)}")

    result = subprocess.run(
        full_command,
        cwd=working_dir,
        capture_output=capture_output,
        text=True
    )

    if result.returncode != 0 and not capture_output:
        raise Exception(f"Terraform command failed with exit code {result.returncode}")

    return result


def get_terraform_output(working_dir: str) -> dict:
    """Get terraform outputs as a dictionary."""
    result = run_terraform(working_dir, ["output", "-json"], capture_output=True)
    if result.returncode != 0:
        raise Exception(f"Failed to get outputs: {result.stderr}")

    outputs = json.loads(result.stdout)
    # Extract just the values
    return {k: v["value"] for k, v in outputs.items()}

# %% [markdown]
# ## Step 1: Deploy Hub Infrastructure
#
# This deploys:
# - Azure API Management
# - Azure OpenAI with model deployments
# - Application Insights

# %%
# Initialize Hub
run_terraform(HUB_DIR, ["init", "-upgrade"])
# Out:
# 📂 infra/hub
# 🔧 Running: terraform init -upgrade
# Initializing the backend...
# Initializing provider plugins...
# - Finding azure/azapi versions matching "~> 2.0"...
# - Finding hashicorp/random versions matching "~> 3.0"...
# - Finding hashicorp/azurerm versions matching "~> 4.0"...
# - Using previously-installed azure/azapi v2.8.0
# - Using previously-installed hashicorp/random v3.8.0
# - Using previously-installed hashicorp/azurerm v4.57.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.
# CompletedProcess(args=['terraform', 'init', '-upgrade'], returncode=0)

# %%
# Apply Hub deployment
run_terraform(HUB_DIR, [
    "apply",
    "-auto-approve",
    f"-var=location={LOCATION}"
])
# Out:
# 📂 infra/hub
# 🔧 Running: terraform apply -auto-approve -var=location=swedencentral
# random_string.suffix: Refreshing state... [id=a8w10w]
# azapi_resource.app_insights_connection: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub/connections/app-insights]
# data.azurerm_client_config.current: Reading...
# azurerm_resource_group.this: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo]
# azurerm_api_management_logger.apim: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/loggers/apim-logger]
# azurerm_application_insights.this: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.Insights/components/insights-a8w10w]
# azurerm_log_analytics_workspace.this: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.OperationalInsights/workspaces/law-a8w10w]
# data.azurerm_client_config.current: Read complete after 0s [id=]
# azurerm_api_management_diagnostic.app_insights: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/diagnostics/applicationinsights]
# azurerm_cognitive_account.this: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w]
# azurerm_api_management.this: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w]
# azurerm_api_management_api.azure_openai: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/apis/azure-openai;rev=1]
# azurerm_role_assignment.apim_can_use_cognitive_services: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/providers/Microsoft.Authorization/roleAssignments/1d23f755-d562-8f4b-1e07-b01fa829f308]
# azurerm_cognitive_account_project.models_hub: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub]
# azurerm_cognitive_deployment.text_embedding_ada_002: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/deployments/text-embedding-ada-002]
# azurerm_role_assignment.currentuser_is_azureaiuser: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/providers/Microsoft.Authorization/roleAssignments/e4ee0e85-5273-4051-3784-6ba4742ab792]
# azurerm_cognitive_deployment.gpt_4o_mini: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/deployments/gpt-4o-mini]
# azapi_resource.azure_openai_backend: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/backends/lmpx-foundry-openai-backend]
# azurerm_api_management_api_policy.azure_openai: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/apis/azure-openai]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   ~ update in-place
#   - destroy
#  <= read (data resources)
#
# Terraform will perform the following actions:
#
#   # data.azapi_resource_action.master_keys will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "azapi_resource_action" "master_keys" {
#       + action                 = "listSecrets"
#       + id                     = (known after apply)
#       + method                 = "POST"
#       + output                 = (known after apply)
#       + resource_id            = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/subscriptions/master"
#       + response_export_values = [
#           + "*",
#         ]
#       + sensitive_output       = (sensitive value)
#       + type                   = "Microsoft.ApiManagement/service/subscriptions@2024-05-01"
#     }
#
#   # azapi_resource.app_insights_connection will be destroyed
#   # (because azapi_resource.app_insights_connection is not in configuration)
#   - resource "azapi_resource" "app_insights_connection" {
#       - body                      = {
#           - properties = {
#               - authType      = "ApiKey"
#               - category      = "AppInsights"
#               - credentials   = {
#                   - key = (sensitive value)
#                 }
#               - isSharedToAll = false
#               - target        = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.Insights/components/insights-a8w10w"
#             }
#         } -> null
#       - id                        = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub/connections/app-insights" -> null
#       - ignore_casing             = false -> null
#       - ignore_missing_property   = true -> null
#       - ignore_null_property      = false -> null
#       - name                      = "app-insights" -> null
#       - output                    = {
#           - id         = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub/connections/app-insights"
#           - properties = {
#               - category                    = "AppInsights"
#               - error                       = null
#               - expiryTime                  = null
#               - group                       = "ServicesAndApps"
#               - isSharedToAll               = false
#               - metadata                    = {}
#               - peRequirement               = "NotRequired"
#               - peStatus                    = "NotApplicable"
#               - sharedUserList              = []
#               - target                      = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.Insights/components/insights-a8w10w"
#               - useWorkspaceManagedIdentity = false
#             }
#           - type       = "Microsoft.CognitiveServices/accounts/projects/connections"
#         } -> null
#       - parent_id                 = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub" -> null
#       - schema_validation_enabled = true -> null
#       - sensitive_body            = (write-only attribute) -> null
#       - type                      = "Microsoft.CognitiveServices/accounts/projects/connections@2025-04-01-preview" -> null
#     }
#
#   # azurerm_api_management.this will be updated in-place
#   ~ resource "azurerm_api_management" "this" {
#         id                            = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w"
#         name                          = "model-gateway-a8w10w"
#       ~ tags                          = {
#           - "CostControl"     = "ignore" -> null
#           - "SecurityControl" = "ignore" -> null
#         }
#         # (21 unchanged attributes hidden)
#
#         # (4 unchanged blocks hidden)
#     }
#
#   # azurerm_api_management_diagnostic.app_insights will be destroyed
#   # (because azurerm_api_management_diagnostic.app_insights is not in configuration)
#   - resource "azurerm_api_management_diagnostic" "app_insights" {
#       - always_log_errors         = true -> null
#       - api_management_logger_id  = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/loggers/apim-logger" -> null
#       - api_management_name       = "model-gateway-a8w10w" -> null
#       - http_correlation_protocol = "W3C" -> null
#       - id                        = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/diagnostics/applicationinsights" -> null
#       - identifier                = "applicationinsights" -> null
#       - log_client_ip             = true -> null
#       - resource_group_name       = "ai-model-gateway-demo" -> null
#       - sampling_percentage       = 100 -> null
#       - verbosity                 = "verbose" -> null
#         # (1 unchanged attribute hidden)
#
#       - backend_request {
#           - body_bytes     = 32 -> null
#           - headers_to_log = [
#               - "accept",
#               - "content-type",
#               - "origin",
#             ] -> null
#         }
#
#       - backend_response {
#           - body_bytes     = 32 -> null
#           - headers_to_log = [
#               - "content-length",
#               - "content-type",
#               - "origin",
#             ] -> null
#         }
#
#       - frontend_request {
#           - body_bytes     = 32 -> null
#           - headers_to_log = [
#               - "accept",
#               - "content-type",
#               - "origin",
#             ] -> null
#         }
#
#       - frontend_response {
#           - body_bytes     = 32 -> null
#           - headers_to_log = [
#               - "content-length",
#               - "content-type",
#               - "origin",
#             ] -> null
#         }
#     }
#
#   # azurerm_api_management_logger.apim will be destroyed
#   # (because azurerm_api_management_logger.apim is not in configuration)
#   - resource "azurerm_api_management_logger" "apim" {
#       - api_management_name = "model-gateway-a8w10w" -> null
#       - buffered            = true -> null
#       - id                  = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/loggers/apim-logger" -> null
#       - name                = "apim-logger" -> null
#       - resource_group_name = "ai-model-gateway-demo" -> null
#         # (2 unchanged attributes hidden)
#
#       - application_insights {
#           - connection_string   = (sensitive value) -> null
#             # (1 unchanged attribute hidden)
#         }
#     }
#
#   # azurerm_application_insights.this will be destroyed
#   # (because azurerm_application_insights.this is not in configuration)
#   - resource "azurerm_application_insights" "this" {
#       - app_id                                = "5b6f8a61-c33b-4e66-9860-3671f35168e0" -> null
#       - application_type                      = "other" -> null
#       - connection_string                     = (sensitive value) -> null
#       - daily_data_cap_in_gb                  = 100 -> null
#       - daily_data_cap_notifications_disabled = false -> null
#       - disable_ip_masking                    = false -> null
#       - force_customer_storage_for_profiler   = false -> null
#       - id                                    = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.Insights/components/insights-a8w10w" -> null
#       - instrumentation_key                   = (sensitive value) -> null
#       - internet_ingestion_enabled            = true -> null
#       - internet_query_enabled                = true -> null
#       - local_authentication_disabled         = false -> null
#       - location                              = "swedencentral" -> null
#       - name                                  = "insights-a8w10w" -> null
#       - resource_group_name                   = "ai-model-gateway-demo" -> null
#       - retention_in_days                     = 90 -> null
#       - sampling_percentage                   = 100 -> null
#       - tags                                  = {
#           - "CostControl"     = "ignore"
#           - "SecurityControl" = "ignore"
#         } -> null
#       - workspace_id                          = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.OperationalInsights/workspaces/law-a8w10w" -> null
#     }
#
#   # azurerm_cognitive_account.this will be updated in-place
#   ~ resource "azurerm_cognitive_account" "this" {
#         id                                          = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w"
#         name                                        = "foundry-hub-a8w10w"
#       ~ tags                                        = {
#           - "CostControl"     = "ignore" -> null
#           - "SecurityControl" = "ignore" -> null
#         }
#         # (20 unchanged attributes hidden)
#
#         # (1 unchanged block hidden)
#     }
#
#   # azurerm_cognitive_account_project.models_hub will be updated in-place
#   ~ resource "azurerm_cognitive_account_project" "models_hub" {
#         id                   = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub"
#         name                 = "models-hub"
#       ~ tags                 = {
#           - "CostControl"     = "ignore" -> null
#           - "SecurityControl" = "ignore" -> null
#         }
#         # (6 unchanged attributes hidden)
#
#         # (1 unchanged block hidden)
#     }
#
#   # azurerm_log_analytics_workspace.this will be destroyed
#   # (because azurerm_log_analytics_workspace.this is not in configuration)
#   - resource "azurerm_log_analytics_workspace" "this" {
#       - allow_resource_only_permissions         = true -> null
#       - cmk_for_query_forced                    = false -> null
#       - daily_quota_gb                          = -1 -> null
#       - id                                      = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.OperationalInsights/workspaces/law-a8w10w" -> null
#       - immediate_data_purge_on_30_days_enabled = false -> null
#       - internet_ingestion_enabled              = true -> null
#       - internet_query_enabled                  = true -> null
#       - local_authentication_disabled           = false -> null
#       - local_authentication_enabled            = true -> null
#       - location                                = "swedencentral" -> null
#       - name                                    = "law-a8w10w" -> null
#       - primary_shared_key                      = (sensitive value) -> null
#       - resource_group_name                     = "ai-model-gateway-demo" -> null
#       - retention_in_days                       = 30 -> null
#       - secondary_shared_key                    = (sensitive value) -> null
#       - sku                                     = "PerGB2018" -> null
#       - tags                                    = {
#           - "CostControl"     = "ignore"
#           - "SecurityControl" = "ignore"
#         } -> null
#       - workspace_id                            = "c856550e-298f-4dfc-91dd-24f5e3fcf151" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # azurerm_resource_group.this will be updated in-place
#   ~ resource "azurerm_resource_group" "this" {
#         id         = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo"
#         name       = "ai-model-gateway-demo"
#       ~ tags       = {
#           - "CostControl"     = "ignore" -> null
#           - "SecurityControl" = "ignore" -> null
#         }
#         # (2 unchanged attributes hidden)
#     }
#
# Plan: 0 to add, 4 to change, 5 to destroy.
#
# Changes to Outputs:
#   ~ apim_subscription_key  = (sensitive value)
# azapi_resource.app_insights_connection: Destroying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub/connections/app-insights]
# azapi_resource.app_insights_connection: Destruction complete after 2s
# azurerm_api_management_diagnostic.app_insights: Destroying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/diagnostics/applicationinsights]
# azurerm_api_management_diagnostic.app_insights: Destruction complete after 1s
# azurerm_api_management_logger.apim: Destroying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/loggers/apim-logger]
# azurerm_api_management_logger.apim: Destruction complete after 1s
# azurerm_application_insights.this: Destroying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.Insights/components/insights-a8w10w]
# azurerm_application_insights.this: Destruction complete after 4s
# azurerm_log_analytics_workspace.this: Destroying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.OperationalInsights/workspaces/law-a8w10w]
# azurerm_log_analytics_workspace.this: Still destroying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-...rationalInsights/workspaces/law-a8w10w, 00m10s elapsed]
# azurerm_log_analytics_workspace.this: Destruction complete after 13s
# azurerm_resource_group.this: Modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo]
# azurerm_resource_group.this: Modifications complete after 3s [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo]
# azurerm_cognitive_account.this: Modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w]
# azurerm_api_management.this: Modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w]
# azurerm_cognitive_account.this: Still modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-...veServices/accounts/foundry-hub-a8w10w, 00m10s elapsed]
# azurerm_api_management.this: Still modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-...anagement/service/model-gateway-a8w10w, 00m10s elapsed]
# azurerm_cognitive_account.this: Modifications complete after 13s [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w]
# azurerm_cognitive_account_project.models_hub: Modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub]
# azurerm_api_management.this: Modifications complete after 14s [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w]
# data.azapi_resource_action.master_keys: Reading...
# data.azapi_resource_action.master_keys: Read complete after 0s [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.ApiManagement/service/model-gateway-a8w10w/subscriptions/master]
# azurerm_cognitive_account_project.models_hub: Still modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-...foundry-hub-a8w10w/projects/models-hub, 00m10s elapsed]
# azurerm_cognitive_account_project.models_hub: Modifications complete after 19s [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-hub-a8w10w/projects/models-hub]
#
# Apply complete! Resources: 0 added, 4 changed, 5 destroyed.
#
# Outputs:
#
# apim_gateway_url = "https://model-gateway-a8w10w.azure-api.net"
# apim_subscription_key = <sensitive>
# azure_openai_endpoint = "https://model-gateway-a8w10w.azure-api.net/openai"
# model_gateway_metadata = {
#   "deploymentInPath" = true
#   "inferenceAPIVersion" = "2024-10-21"
#   "models" = [
#     {
#       "name" = "gpt-4o-mini"
#       "properties" = {
#         "model" = {
#           "format" = "OpenAI"
#           "name" = "gpt-4o-mini"
#           "version" = "2024-07-18"
#         }
#       }
#     },
#     {
#       "name" = "text-embedding-ada-002"
#       "properties" = {
#         "model" = {
#           "format" = "OpenAI"
#           "name" = "text-embedding-ada-002"
#           "version" = "2"
#         }
#       }
#     },
#   ]
# }
# resource_group_name = "ai-model-gateway-demo"
# CompletedProcess(args=['terraform', 'apply', '-auto-approve', '-var=location=swedencentral'], returncode=0)

# %%
# Get Hub outputs
hub_outputs = get_terraform_output(HUB_DIR)
print("\n✅ Hub outputs:")
for key, value in hub_outputs.items():
    if "key" in key.lower():
        print(f"   {key}: ***REDACTED***")
    else:
        print(f"   {key}: {value}")
# Out:
# 📂 infra/hub
# 🔧 Running: terraform output -json
#
# ✅ Hub outputs:
#    apim_gateway_url: https://model-gateway-a8w10w.azure-api.net
#    apim_subscription_key: ***REDACTED***
#    azure_openai_endpoint: https://model-gateway-a8w10w.azure-api.net/openai
#    model_gateway_metadata: {'deploymentInPath': True, 'inferenceAPIVersion': '2024-10-21', 'models': [{'name': 'gpt-4o-mini', 'properties': {'model': {'format': 'OpenAI', 'name': 'gpt-4o-mini', 'version': '2024-07-18'}}}, {'name': 'text-embedding-ada-002', 'properties': {'model': {'format': 'OpenAI', 'name': 'text-embedding-ada-002', 'version': '2'}}}]}
#    resource_group_name: ai-model-gateway-demo

# %% [markdown]
# ## Step 2: Deploy Spoke Infrastructure
#
# This deploys:
# - AI Foundry Account and Project
# - Model Gateway connection to APIM

# %%
# Initialize Spoke
run_terraform(SPOKE_DIR, ["init", "-upgrade"])
# Out:
# 📂 infra/spoke
# 🔧 Running: terraform init -upgrade
# Initializing the backend...
# Initializing provider plugins...
# - Finding azure/azapi versions matching "~> 2.0"...
# - Finding hashicorp/azurerm versions matching "~> 4.0"...
# - Finding latest version of hashicorp/random...
# - Using previously-installed hashicorp/random v3.8.0
# - Using previously-installed azure/azapi v2.8.0
# - Using previously-installed hashicorp/azurerm v4.57.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.
# CompletedProcess(args=['terraform', 'init', '-upgrade'], returncode=0)

# %%
# Prepare spoke variables from hub outputs
model_gateway_var = json.dumps({
    "url": hub_outputs["azure_openai_endpoint"],
    "api_key": hub_outputs["apim_subscription_key"],
    "metadata": hub_outputs["model_gateway_metadata"]
})

# Apply Spoke deployment
run_terraform(SPOKE_DIR, [
    "apply",
    "-auto-approve",
    f"-var=resource_group_name={hub_outputs['resource_group_name']}",
    f"-var=location={LOCATION}",
    f"-var=model_gateway={model_gateway_var}"
])
# Out:
# 📂 infra/spoke
# 🔧 Running: terraform apply -auto-approve -var=resource_group_name=ai-model-gateway-demo -var=location=swedencentral -var=model_gateway={"url": "https://model-gateway-a8w10w.azure-api.net/openai", "api_key": "c3ea48b4301f43c0b0f4346677ecaf89", "metadata": {"deploymentInPath": true, "inferenceAPIVersion": "2024-10-21", "models": [{"name": "gpt-4o-mini", "properties": {"model": {"format": "OpenAI", "name": "gpt-4o-mini", "version": "2024-07-18"}}}, {"name": "text-embedding-ada-002", "properties": {"model": {"format": "OpenAI", "name": "text-embedding-ada-002", "version": "2"}}}]}}
# random_string.suffix: Refreshing state... [id=fcdkn7]
# data.azurerm_client_config.current: Reading...
# azurerm_cognitive_account.this: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7]
# data.azurerm_client_config.current: Read complete after 0s [id=]
# azurerm_cognitive_account_project.project: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7/projects/my-project]
# azurerm_role_assignment.currentuser_is_azureaiuser: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7/providers/Microsoft.Authorization/roleAssignments/db545d5d-9dca-74a6-2416-b1203be1d807]
# azapi_resource.model_gateway_connection: Refreshing state... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7/projects/my-project/connections/model-gateway]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   ~ update in-place
#
# Terraform will perform the following actions:
#
#   # azurerm_cognitive_account.this will be updated in-place
#   ~ resource "azurerm_cognitive_account" "this" {
#         id                                          = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7"
#         name                                        = "foundry-spoke-fcdkn7"
#       ~ tags                                        = {
#           - "CostControl"     = "ignore" -> null
#           - "SecurityControl" = "ignore" -> null
#         }
#         # (20 unchanged attributes hidden)
#
#         # (1 unchanged block hidden)
#     }
#
#   # azurerm_cognitive_account_project.project will be updated in-place
#   ~ resource "azurerm_cognitive_account_project" "project" {
#         id                   = "/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7/projects/my-project"
#         name                 = "my-project"
#       ~ tags                 = {
#           - "CostControl"     = "ignore" -> null
#           - "SecurityControl" = "ignore" -> null
#         }
#         # (6 unchanged attributes hidden)
#
#         # (1 unchanged block hidden)
#     }
#
# Plan: 0 to add, 2 to change, 0 to destroy.
# azurerm_cognitive_account.this: Modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7]
# azurerm_cognitive_account.this: Still modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-...Services/accounts/foundry-spoke-fcdkn7, 00m10s elapsed]
# azurerm_cognitive_account.this: Modifications complete after 13s [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7]
# azurerm_cognitive_account_project.project: Modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7/projects/my-project]
# azurerm_cognitive_account_project.project: Still modifying... [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-...undry-spoke-fcdkn7/projects/my-project, 00m10s elapsed]
# azurerm_cognitive_account_project.project: Modifications complete after 19s [id=/subscriptions/1c8a30db-49c5-45f2-a0e4-63295d5f6324/resourceGroups/ai-model-gateway-demo/providers/Microsoft.CognitiveServices/accounts/foundry-spoke-fcdkn7/projects/my-project]
#
# Apply complete! Resources: 0 added, 2 changed, 0 destroyed.
#
# Outputs:
#
# cognitive_account_endpoint = "https://foundry-spoke-fcdkn7.cognitiveservices.azure.com/"
# cognitive_account_name = "foundry-spoke-fcdkn7"
# project_endpoint = "https://foundry-spoke-fcdkn7.services.ai.azure.com/api/projects/my-project"
# project_name = "my-project"
# CompletedProcess(args=['terraform', 'apply', '-auto-approve', '-var=resource_group_name=ai-model-gateway-demo', '-var=location=swedencentral', '-var=model_gateway={"url": "https://model-gateway-a8w10w.azure-api.net/openai", "api_key": "c3ea48b4301f43c0b0f4346677ecaf89", "metadata": {"deploymentInPath": true, "inferenceAPIVersion": "2024-10-21", "models": [{"name": "gpt-4o-mini", "properties": {"model": {"format": "OpenAI", "name": "gpt-4o-mini", "version": "2024-07-18"}}}, {"name": "text-embedding-ada-002", "properties": {"model": {"format": "OpenAI", "name": "text-embedding-ada-002", "version": "2"}}}]}}'], returncode=0)

# %%
# Get Spoke outputs
spoke_outputs = get_terraform_output(SPOKE_DIR)
print("\n✅ Spoke outputs:")
for key, value in spoke_outputs.items():
    print(f"   {key}: {value}")
# Out:
# 📂 infra/spoke
# 🔧 Running: terraform output -json
#
# ✅ Spoke outputs:
#    cognitive_account_endpoint: https://foundry-spoke-fcdkn7.cognitiveservices.azure.com/
#    cognitive_account_name: foundry-spoke-fcdkn7
#    project_endpoint: https://foundry-spoke-fcdkn7.services.ai.azure.com/api/projects/my-project
#    project_name: my-project

# %% [markdown]
# ## Step 3: Generate .env File
#
# Create the `.env` file required by `deploy_agent.py` and `test_agent.py`

# %%
# Generate .env content
env_content = f"""# Auto-generated by deployment notebook - do not edit manually

# Azure Configuration
AZURE_SUBSCRIPTION_ID={os.environ['ARM_SUBSCRIPTION_ID']}
AZURE_RESOURCE_GROUP={hub_outputs['resource_group_name']}

# AI Foundry Configuration
AZURE_AI_ACCOUNT_NAME={spoke_outputs['cognitive_account_name']}
AZURE_AI_PROJECT_NAME={spoke_outputs['project_name']}
AZURE_AI_PROJECT_ENDPOINT={spoke_outputs['project_endpoint']}

# Agent Configuration
AGENT_NAME=APIMGatewayAgent
AGENT_MODEL=model-gateway/gpt-4o-mini
"""

# Write .env file
with open(".env", "w") as f:
    f.write(env_content)

print("✅ Generated .env file:")
print("-" * 40)
# Print without sensitive data
for line in env_content.split("\n"):
    if line and not line.startswith("#"):
        print(f"   {line}")
# Out:
# ✅ Generated .env file:
# ----------------------------------------
#    AZURE_SUBSCRIPTION_ID=1c8a30db-49c5-45f2-a0e4-63295d5f6324
#    AZURE_RESOURCE_GROUP=ai-model-gateway-demo
#    AZURE_AI_ACCOUNT_NAME=foundry-spoke-fcdkn7
#    AZURE_AI_PROJECT_NAME=my-project
#    AZURE_AI_PROJECT_ENDPOINT=https://foundry-spoke-fcdkn7.services.ai.azure.com/api/projects/my-project
#    AGENT_NAME=APIMGatewayAgent
#    AGENT_MODEL=model-gateway/gpt-4o-mini

# %% [markdown]
# ## Step 4: Deploy Agent
#
# Run `deploy_agent.py` to create the agent in AI Foundry

# %%
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import PromptAgentDefinition
from azure.identity import DefaultAzureCredential

# Agent configuration
AGENT_NAME = "APIMGatewayAgent"
AGENT_MODEL = "model-gateway/gpt-4o-mini"

print("🚀 Deploying Agent via AI Gateway")
print("=" * 60)

# Initialize the project client
print("\n📡 Connecting to Azure AI Foundry project...")
print(f"   Project: {spoke_outputs['project_name']}")
print(f"   Endpoint: {spoke_outputs['project_endpoint']}")

project_client = AIProjectClient(
    endpoint=spoke_outputs['project_endpoint'],
    credential=DefaultAzureCredential()
)
print("✅ Connected successfully")

# Create an agent using the AI Gateway connection
print("\n🤖 Creating agent with AI Gateway connection...")
print(f"   Model: {AGENT_MODEL}")
print("   (This routes through APIM to Azure OpenAI)")

with project_client:
    agent = project_client.agents.create_version(
        agent_name=AGENT_NAME,
        definition=PromptAgentDefinition(
            model=AGENT_MODEL,
            instructions="You are a helpful AI assistant deployed via Azure API Management. "
            "All your requests are routed through APIM for monitoring and governance.",
        ),
    )

print("\n" + "=" * 60)
print("🎉 Agent Deployment Complete!")
print("=" * 60)
print("\n📋 Agent Details:")
print(f"   Agent Name: {agent.name}")
print(f"   Agent Version: {agent.version}")
print(f"   Model: {AGENT_MODEL}")
# Out:
# 🚀 Deploying Agent via AI Gateway
# ============================================================
#
# 📡 Connecting to Azure AI Foundry project...
#    Project: my-project
#    Endpoint: https://foundry-spoke-fcdkn7.services.ai.azure.com/api/projects/my-project
# ✅ Connected successfully
#
# 🤖 Creating agent with AI Gateway connection...
#    Model: model-gateway/gpt-4o-mini
#    (This routes through APIM to Azure OpenAI)
#
# ============================================================
# 🎉 Agent Deployment Complete!
# ============================================================
#
# 📋 Agent Details:
#    Agent Name: APIMGatewayAgent
#    Agent Version: 1
#    Model: model-gateway/gpt-4o-mini

# %% [markdown]
# ## Step 5: Test Agent
#
# Run `test_agent.py` to verify the agent works through the APIM gateway

# %%
print("🧪 Testing APIM Gateway Prompt Agent")
print("=" * 60)

project_client = AIProjectClient(
    endpoint=spoke_outputs['project_endpoint'],
    credential=DefaultAzureCredential()
)

with project_client:
    print(f"\n📋 Using Agent: {agent.name} (version {agent.version})")
    print(f"   Model: {AGENT_MODEL}")
    print("   (Routes through APIM)")

    # Test message
    test_message = "Hello! Please tell me a short joke about AI and API gateways."
    print(f"\n💬 User: {test_message}")

    print("\n🔄 Processing through APIM Gateway...")

    # Use the OpenAI client and Conversations/Responses API
    with project_client.get_openai_client() as openai_client:
        # Create a conversation with initial user message
        conversation = openai_client.conversations.create(
            items=[{"type": "message", "role": "user", "content": test_message}],
        )
        print(f"   Conversation created: {conversation.id}")

        # Get response from agent
        response = openai_client.responses.create(
            conversation=conversation.id,
            extra_body={"agent": {"name": agent.name, "type": "agent_reference"}},
            input="",
        )

        print("\n🤖 Assistant Response:")
        print(f"   {response.output_text}")

print("\n" + "=" * 60)
print("✅ Test Complete!")
print("=" * 60)
print("\n📊 Request Flow:")
print("   1. Python SDK → Azure AI Foundry Project")
print("   2. Foundry → model-gateway connection")
print(f"   3. Connection → APIM ({hub_outputs['apim_gateway_url']})")
print("   4. APIM → Azure OpenAI (via managed identity)")
print("   5. Response flows back through APIM (with monitoring/governance)")
# Out:
# 🧪 Testing APIM Gateway Prompt Agent
# ============================================================
#
# 📋 Using Agent: APIMGatewayAgent (version 1)
#    Model: model-gateway/gpt-4o-mini
#    (Routes through APIM)
#
# 💬 User: Hello! Please tell me a short joke about AI and API gateways.
#
# 🔄 Processing through APIM Gateway...
#    Conversation created: conv_2bd570c9e8b95e0e0066nXFBRBuCm2FUlH9jrpXoyPhhmsxoai
#
# 🤖 Assistant Response:
#    Why did the AI break up with the API gateway?
#
# Because it couldn’t handle all the requests for attention!
#
# ============================================================
# ✅ Test Complete!
# ============================================================
#
# 📊 Request Flow:
#    1. Python SDK → Azure AI Foundry Project
#    2. Foundry → model-gateway connection
#    3. Connection → APIM (https://model-gateway-a8w10w.azure-api.net)
#    4. APIM → Azure OpenAI (via managed identity)
#    5. Response flows back through APIM (with monitoring/governance)

# %% [markdown]
# ## Cleanup (Optional)
#
# Destroy all infrastructure when done testing

# %%
# ⚠️ DANGER: Uncomment to destroy all resources
# print("🗑️ Destroying Spoke...")
# run_terraform(SPOKE_DIR, ["destroy", "-auto-approve",
#     f"-var=resource_group_name={hub_outputs['resource_group_name']}",
#     f"-var=location={LOCATION}",
#     f"-var=model_gateway={model_gateway_var}"
# ])

# print("🗑️ Destroying Hub...")
# run_terraform(HUB_DIR, ["destroy", "-auto-approve",
#     f"-var=location={LOCATION}"
# ])

# print("✅ All resources destroyed")
